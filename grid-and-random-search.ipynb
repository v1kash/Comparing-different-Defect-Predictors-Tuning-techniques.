# %%
#import lib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('../input/software-defect-prediction/jm1.csv')

df['uniq_Op'] = pd.to_numeric(df['uniq_Op'], errors='coerce') ## convert to number, make NaNs from ?s 
df['uniq_Opnd'] = pd.to_numeric(df['uniq_Opnd'], errors='coerce') ## convert to number, make NaNs from ?s 
df['total_Op'] = pd.to_numeric(df['total_Op'], errors='coerce') ## convert to number, make NaNs from ?s 
df['total_Opnd'] = pd.to_numeric(df['total_Opnd'], errors='coerce') ## convert to number, make NaNs from ?s 
df['branchCount'] = pd.to_numeric(df['branchCount'], errors='coerce') ## convert to number, make NaNs from ?s 
df['defects'] = df['defects'].astype(int)

df = df.dropna()
df = df.reset_index(drop=True)

# %%
from sklearn import model_selection

# Split-out validation dataset
array = df.values
X = array[:,0:21]
Y = array[:,21]

# Get Training and Validation sets
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=0.2, random_state=7)

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='rbf',random_state=0)
# %time classifier.fit(X_train,Y_train)

#predicting
y_pred=classifier.predict(X_validation)
# Out:
# CPU times: user 2.06 s, sys: 101 ms, total: 2.16 s
# Wall time: 2.16 s

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
#print("1. Accuracy: {}".format(accuracy_score(Y_validation, y_pred)))
#print("2. Confusion Matrix:n{}".format(pd.crosstab(Y_validation, y_pred, rownames=['True'], colnames=['Predicted'])))
#f1_score(Y_validation, y_pred, average='weighted')
print('Accuracy Score : ' + str(accuracy_score(Y_validation,y_pred)))
print('Precision Score : ' + str(precision_score(Y_validation,y_pred)))
print('Recall Score : ' + str(recall_score(Y_validation,y_pred)))
print('F1 Score : ' + str(f1_score(Y_validation,y_pred)))

from sklearn.metrics import confusion_matrix
print('Confusion Matrix : \n' + str(confusion_matrix(Y_validation,y_pred)))
# Out:
# Accuracy Score : 0.8226102941176471
# Precision Score : 0.45454545454545453
# Recall Score : 0.012987012987012988
# F1 Score : 0.025252525252525252
# Confusion Matrix :
# [[1785    6]
#  [ 380    5]]

# %% [markdown]
# Grid Search Implementation:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

classifier=SVC(kernel='rbf',random_state=0)
parameters={'C':[1e-2,1e-1,1,1e1,0.009,0.01,0.09,5,10,25],'kernel':['rbf'],'gamma':[0.1,0.01,1e-5,1e-4,1e-3]}
grid = GridSearchCV(classifier,parameters,n_jobs=-1,cv=3,scoring='accuracy')
# %time grid = grid.fit(X_train,Y_train)
best_acc = grid.best_score_
best_param = grid.best_params_
# Out:
# CPU times: user 8.94 s, sys: 135 ms, total: 9.08 s
# Wall time: 3min 16s

# %%
print(best_acc)
print(best_param)
pd.DataFrame(grid.cv_results_)
# Out:
# 0.8059514400200886
# {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        3.674464      0.509310         1.501023        0.387501    0.01
# 1        2.881842      0.225188         1.151705        0.024304    0.01
# 2        1.802663      0.317237         0.775572        0.128992    0.01
# 3        1.830529      0.075404         0.786479        0.010908    0.01
# 4        2.735884      0.582229         1.157212        0.260447    0.01
# 5        3.333700      0.041869         1.552585        0.312747     0.1
# 6        3.815570      0.406086         1.311980        0.192325     0.1
# 7        2.277103      0.344021         0.873853        0.193365     0.1
# 8        2.759888      0.522684         1.059011        0.235076     0.1
# 9        3.056679      0.092893         1.129583        0.141846     0.1
# 10       4.065608      0.314166         1.553369        0.359976       1
# 11       4.100441      0.081721         1.250579        0.100894       1
# 12       2.959466      0.211018         0.819558        0.129756       1
# 13       3.184325      0.624701         0.827578        0.228794       1
# 14       3.161590      0.078878         0.990304        0.094033       1
# 15       4.365438      0.615942         1.505586        0.296969      10
# 16       5.254578      0.718250         1.502637        0.248943      10
# 17       4.202511      0.440489         0.706981        0.014884      10
# 18       4.410742      0.653579         0.927369        0.192637      10
# 19       5.559794      0.306871         0.994734        0.010514      10
# 20       3.568300      0.934516         1.529434        0.354824   0.009
# 21       3.412143      0.492487         1.368673        0.303951   0.009
# 22       1.463680      0.069122         0.674474        0.007238   0.009
# 23       2.209011      0.552230         0.928024        0.204962   0.009
# 24       2.280231      0.055056         1.113865        0.195071   0.009
# 25       3.229322      0.180041         1.517642        0.365015    0.01
# 26       3.338195      0.573505         1.238425        0.093044    0.01
# 27       1.903599      0.402510         0.703898        0.151780    0.01
# 28       2.034499      0.501812         0.945414        0.235727    0.01
# 29       2.742592      0.411500         1.324955        0.203642    0.01
# 30       3.318163      0.117515         1.345530        0.066321    0.09
# 31       3.628141      0.854525         1.364394        0.411726    0.09
# 32       1.718335      0.132225         0.748553        0.018396    0.09
# 33       2.612408      0.508637         1.007103        0.218700    0.09
# 34       2.956110      0.204345         0.991117        0.062924    0.09
# 35       4.389984      0.886073         1.562736        0.265638       5
# 36       5.523022      0.586761         1.407409        0.330759       5
# 37       3.543875      0.087680         0.711471        0.052459       5
# 38       3.548912      0.330911         0.850476        0.035201       5
# 39       5.695401      0.751590         1.190612        0.265866       5
# 40       4.319510      0.615363         1.543505        0.327610      10
# 41       5.149931      0.204180         1.180828        0.017293      10
# 42       4.619915      0.485539         0.843726        0.199478      10
# 43       4.314089      0.451221         0.863591        0.029258      10
# 44       6.907179      0.898628         1.171164        0.078348      10
# 45       4.748142      0.649173         1.275520        0.036532      25
# 46       6.552574      0.884253         1.386240        0.309751      25
# 47       6.032290      0.651057         0.844342        0.193726      25
# 48       4.999914      0.219660         0.831511        0.016856      25
# 49       6.635493      0.801152         1.103568        0.201615      25
#
#    param_gamma param_kernel                                          params  \
# 0          0.1          rbf      {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# 1         0.01          rbf     {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 2        1e-05          rbf    {'C': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}
# 3       0.0001          rbf   {'C': 0.01, 'gamma': 0.0001, 'kernel': 'rbf'}
# 4        0.001          rbf    {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# 5          0.1          rbf       {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 6         0.01          rbf      {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 7        1e-05          rbf     {'C': 0.1, 'gamma': 1e-05, 'kernel': 'rbf'}
# 8       0.0001          rbf    {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 9        0.001          rbf     {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 10         0.1          rbf         {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 11        0.01          rbf        {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 12       1e-05          rbf       {'C': 1, 'gamma': 1e-05, 'kernel': 'rbf'}
# 13      0.0001          rbf      {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 14       0.001          rbf       {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 15         0.1          rbf      {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 16        0.01          rbf     {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'}
# 17       1e-05          rbf    {'C': 10.0, 'gamma': 1e-05, 'kernel': 'rbf'}
# 18      0.0001          rbf   {'C': 10.0, 'gamma': 0.0001, 'kernel': 'rbf'}
# 19       0.001          rbf    {'C': 10.0, 'gamma': 0.001, 'kernel': 'rbf'}
# 20         0.1          rbf     {'C': 0.009, 'gamma': 0.1, 'kernel': 'rbf'}
# 21        0.01          rbf    {'C': 0.009, 'gamma': 0.01, 'kernel': 'rbf'}
# 22       1e-05          rbf   {'C': 0.009, 'gamma': 1e-05, 'kernel': 'rbf'}
# 23      0.0001          rbf  {'C': 0.009, 'gamma': 0.0001, 'kernel': 'rbf'}
# 24       0.001          rbf   {'C': 0.009, 'gamma': 0.001, 'kernel': 'rbf'}
# 25         0.1          rbf      {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# 26        0.01          rbf     {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 27       1e-05          rbf    {'C': 0.01, 'gamma': 1e-05, 'kernel': 'rbf'}
# 28      0.0001          rbf   {'C': 0.01, 'gamma': 0.0001, 'kernel': 'rbf'}
# 29       0.001          rbf    {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# 30         0.1          rbf      {'C': 0.09, 'gamma': 0.1, 'kernel': 'rbf'}
# 31        0.01          rbf     {'C': 0.09, 'gamma': 0.01, 'kernel': 'rbf'}
# 32       1e-05          rbf    {'C': 0.09, 'gamma': 1e-05, 'kernel': 'rbf'}
# 33      0.0001          rbf   {'C': 0.09, 'gamma': 0.0001, 'kernel': 'rbf'}
# 34       0.001          rbf    {'C': 0.09, 'gamma': 0.001, 'kernel': 'rbf'}
# 35         0.1          rbf         {'C': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# 36        0.01          rbf        {'C': 5, 'gamma': 0.01, 'kernel': 'rbf'}
# 37       1e-05          rbf       {'C': 5, 'gamma': 1e-05, 'kernel': 'rbf'}
# 38      0.0001          rbf      {'C': 5, 'gamma': 0.0001, 'kernel': 'rbf'}
# 39       0.001          rbf       {'C': 5, 'gamma': 0.001, 'kernel': 'rbf'}
# 40         0.1          rbf        {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 41        0.01          rbf       {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 42       1e-05          rbf      {'C': 10, 'gamma': 1e-05, 'kernel': 'rbf'}
# 0         0.000149                4
# 1         0.000149                4
# 2         0.000149                4
# 3         0.000149                4
# 4         0.000149                4
# 5         0.000149                4
# 6         0.000149                4
# 7         0.000149                4
# 8         0.001078               28
# 9         0.000149                4
# 10        0.001790                2
# 11        0.001266                1
# 12        0.003693               31
# 13        0.003571               30
# 14        0.000472                3
# 15        0.001479               32
# 16        0.002700               35
# 17        0.001549               40
# 18        0.005843               47
# 19        0.001686               44
# 20        0.000149                4
# 21        0.000149                4
# 22        0.000149                4
# 23        0.000149                4
# 24        0.000149                4
# 25        0.000149                4
# 26        0.000149                4
# 27        0.000149                4
# 28        0.000149                4
# 29        0.000149                4
# 30        0.000149                4
# 31        0.000149                4
# 32        0.000149                4
# 33        0.000596               27
# 34        0.000149                4
# 35        0.001149               29
# 36        0.003157               34
# 37        0.001413               39
# 38        0.007054               43
# 39        0.000827               42
# 40        0.001479               32
# 41        0.002700               35
# 42        0.001549               40
# 43        0.005843               47
# 44        0.001686               44
# 45        0.001007               38
# 46        0.002255               37
# 47        0.001643               46
# 48        0.006668               50
# 49        0.002789               49

# %% [markdown]
# random search implemenatation:

# %%
from sklearn.model_selection import RandomizedSearchCV

from sklearn.svm import SVC
classifier=SVC(kernel='rbf',random_state=0)
parameters={'C':[1e-2,1e-1,1,1e1,0.009,0.01,0.09,5,10,25],'kernel':['rbf'],'gamma':[0.1,0.01,1e-5,1e-4,1e-3]}
random =RandomizedSearchCV(classifier,parameters,n_iter=10,cv=3,scoring='accuracy',n_jobs=-1)
# %time random=random.fit(X_train,Y_train)
best_acc=random.best_score_
best_param=random.best_params_
# Out:
# CPU times: user 8.61 s, sys: 69.9 ms, total: 8.68 s
# Wall time: 22.6 s

# %%
print(best_acc)
print(best_param)
pd.DataFrame(random.cv_results_)
# Out:
# 0.8059514400200886
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       3.078562      0.129283         0.594812        0.003686          rbf
# 1       1.981578      0.075742         0.796105        0.006507          rbf
# 2       3.250725      0.375014         1.163609        0.010201          rbf
# 3       2.672245      0.073355         0.865898        0.100789          rbf
# 4       4.760247      0.291469         0.959716        0.004096          rbf
#
#   param_gamma param_C                                        params  \
# 0       1e-05      10  {'kernel': 'rbf', 'gamma': 1e-05, 'C': 10.0}
# 1      0.0001     0.1  {'kernel': 'rbf', 'gamma': 0.0001, 'C': 0.1}
# 2        0.01       1    {'kernel': 'rbf', 'gamma': 0.01, 'C': 1.0}
# 3       0.001       1   {'kernel': 'rbf', 'gamma': 0.001, 'C': 1.0}
# 4       0.001      10  {'kernel': 'rbf', 'gamma': 0.001, 'C': 10.0}
#
#    split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0           0.788766           0.790762           0.786970         0.788833
# 1           0.802550           0.802827           0.800414         0.801930
# 2           0.804618           0.807653           0.805584         0.805951
# 3           0.804962           0.805929           0.804895         0.805262
# 4           0.782908           0.785591           0.786970         0.785157
#
#    std_test_score  rank_test_score
# 0        0.001549                4
# 1        0.001078                3
# 2        0.001266                1
# 3        0.000472                2
# 4        0.001686                5
